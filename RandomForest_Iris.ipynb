# %%
import matplotlib
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

# %%
iris = load_iris()

# %%
iris_data = pd.DataFrame(iris.data, columns = iris.feature_names)

# %%
target = pd.DataFrame(iris.target, columns=['target'])

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=77)

# %%
clf = DecisionTreeClassifier(max_depth = 4, criterion='entropy') 
clf.fit(X_train, y_train)                                        
target_pred = clf.predict(X_test)
print('Predicción: ', target_pred)
print('Real:       ', y_test)
# Out:
# Predicción:  [1 1 2 1 0 2 2 1 0 1 0 1 0 0 0 2 2 2 0 1 0 2 2 1 1 1 2 0 1 1 1 1 0 2 2 1 1
#  2 1 2 0 1 0 0 2 0 1 2 1 0 1 1 2 0 0 0 1 2 0 0]
# Real:        [1 2 2 1 0 2 2 2 0 1 0 2 0 0 0 2 2 2 0 1 0 2 2 1 1 1 2 0 1 2 1 2 0 2 2 1 1
#  2 1 2 0 1 0 0 1 0 1 2 1 0 1 1 2 0 0 0 1 2 0 0]

# %%
disp = plot_confusion_matrix(clf, X_test, y_test,
                                 display_labels=iris.target_names,
                                 cmap=plt.cm.Blues,
                                 normalize='true')
disp.ax_.set_title('Matriz de confusión')
# Out:
# Text(0.5, 1.0, 'Matriz de confusión')

# %%
from matplotlib import pyplot as plt
from sklearn import tree

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)

# %%
import graphviz

dot_data = tree.export_graphviz(clf, out_file=None, 
                                feature_names=iris.feature_names,  
                                class_names=iris.target_names,
                                filled=True)

# Dibujar Gráfica
graph = graphviz.Source(dot_data, format="png") 
graph
